# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Angshuman Bardhan\Desktop\OlympicAthletes.csv")
df
# Out:
#                         Athlete        Country  Year  \
# 0                    Yang Yilin          China  2008
# 1                  Leisel Jones      Australia  2000
# 2                   Go Gi-Hyeon    South Korea  2002
# 3                   Chen Ruolin          China  2008
# 4                 Katie Ledecky  United States  2012
# 5                Ruta Meilutyte      Lithuania  2012
# 6                 Dániel Gyurta        Hungary  2004
# 7               Arianna Fontana          Italy  2006
# 8                Olga Glatskikh         Russia  2004
# 9            Kharikleia Pantazi         Greece  2000
# 10                   Kim Martin         Sweden  2002
# 11                    Kyla Ross  United States  2012
# 12              Gabriela Dragoi        Romania  2008
# 13       Tasha Schwikert-Warren  United States  2000
# 14                     Yang Yun          China  2000
# 15                 Sophie Lamon    Switzerland  2000
# 16             Alejandra Orozco         Mexico  2012
# ...

# %%
df1=df.dropna()
df1
# Out:
#                         Athlete        Country  Year  \
# 0                    Yang Yilin          China  2008
# 1                  Leisel Jones      Australia  2000
# 2                   Go Gi-Hyeon    South Korea  2002
# 3                   Chen Ruolin          China  2008
# 4                 Katie Ledecky  United States  2012
# 5                Ruta Meilutyte      Lithuania  2012
# 6                 Dániel Gyurta        Hungary  2004
# 7               Arianna Fontana          Italy  2006
# 8                Olga Glatskikh         Russia  2004
# 9            Kharikleia Pantazi         Greece  2000
# 10                   Kim Martin         Sweden  2002
# 11                    Kyla Ross  United States  2012
# 12              Gabriela Dragoi        Romania  2008
# 13       Tasha Schwikert-Warren  United States  2000
# 14                     Yang Yun          China  2000
# 15                 Sophie Lamon    Switzerland  2000
# 16             Alejandra Orozco         Mexico  2012
# ...

# %%
#Top medal score with country name (top 5)

# %%
df1=df.groupby(['Country'])['Total'].sum()

# %%
df1
# Out:
# Country
# Afghanistan                 2
# Algeria                     8
# Argentina                 141
# Armenia                    10
# Australia                 609
# Austria                    91
# Azerbaijan                 25
# Bahamas                    24
# Bahrain                     1
# Barbados                    1
# Belarus                    97
# Belgium                    18
# Botswana                    1
# Brazil                    221
# Bulgaria                   41
# Cameroon                   20
# Canada                    370
# Chile                      22
# China                     530
# Chinese Taipei             20
# Colombia                   13
# Costa Rica                  2
# Croatia                    81
# Cuba                      188
# Cyprus                      1
# Czech Republic             81
# Denmark                    89
# Dominican Republic          5
# Ecuador                     1
# Egypt                       8
# ...

# %%
df1.sort_values(ascending=False).head(5)
# Out:
# Country
# United States    1312
# Russia            768
# Germany           629
# Australia         609
# China             530
# Name: Total, dtype: int64

# %%
#Countries who won more medals in swimming

# %%
df2=df1.groupby(['Country']).filter(lambda x:(x['Sport']=='Swimming').all())
df2
# Out:
#               Athlete     Country  Year     Sport  Gold  Silver  Bronze  Total
# 511   Kirsty Coventry    Zimbabwe  2004  Swimming     1       1       1      3
# 2629  Kirsty Coventry    Zimbabwe  2008  Swimming     1       3       0      4
# 4747     Claudia Poll  Costa Rica  2000  Swimming     0       0       2      2

# %%
df2.groupby(['Country'])['Total'].sum()
# Out:
# Country
# Costa Rica    2
# Zimbabwe      7
# Name: Total, dtype: int64

# %%
df1.groupby

# %%
#Total no. of Atheles participated in each country

# %%
df3=df1[['Athlete','Country']]
df3
# Out:
#                         Athlete        Country
# 0                    Yang Yilin          China
# 1                  Leisel Jones      Australia
# 2                   Go Gi-Hyeon    South Korea
# 3                   Chen Ruolin          China
# 4                 Katie Ledecky  United States
# 5                Ruta Meilutyte      Lithuania
# 6                 Dániel Gyurta        Hungary
# 7               Arianna Fontana          Italy
# 8                Olga Glatskikh         Russia
# 9            Kharikleia Pantazi         Greece
# 10                   Kim Martin         Sweden
# 11                    Kyla Ross  United States
# 12              Gabriela Dragoi        Romania
# 13       Tasha Schwikert-Warren  United States
# 14                     Yang Yun          China
# 15                 Sophie Lamon    Switzerland
# 16             Alejandra Orozco         Mexico
# 17             Yuliya Koltunova         Russia
# 18                Shawn Johnson  United States
# ...

# %%
# %matplotlib inline 
df1.plot(y='Total',label='Country')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0,0.1,0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,
         startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
